# %% [markdown]
# Clase 6: https://www.youtube.com/watch?v=MEzG0BEpyps&list=PLZJ968vUBsqzWZ0UNzuMo_z5OqViD94hy&index=6

# %% [markdown]
# <p><a name="contents"></a></p>
#
# # **Ejercicios Sesión 3**
#
# - <a href="#s1">01. Operadores</a><br>
# - <a href="#s2">02. Listas, tuplas, diccionarios y conjuntos (Conocidos como Python Collections (Arrays))</a><br>

# %% [markdown]
# <p><a name="s1"></a></p>
#
# # **01. Operadores**
# [[Contenidos]](#contents)
#
# <p>
# Los operadores se utilizan para realizar operaciones sobre variables y valores. En el siguiente ejemplo, usamos el operador + para sumar dos valores:
#
# Python divide los operadores en los siguientes grupos:
#
#
# *   Operadores aritméticos
# *   Operadores de Asignación
# *   Operadores de comparación
# *   Operadores logicos
# *   Operadores de identidad
# *   Operadores de membresía o de presencia
#
# </p>

# %% [markdown]
# ## Ejercicio 1
# <p>
# Realizar un algoritmo que solucione ecuaciones cuadráticas.
#
# ![Imagen](https://i.pinimg.com/originals/19/ab/87/19ab870784d018c47ad9b36c6da9c2c8.gif)
#
# </p>

# %%
#Solucion

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.28.33 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.29.06 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ## Ejercicio 2
# <p>
# Realizar una función que utilizando el teorema del Seno solucione para un Angulo y para un lado de su elección.
# </p>
#
# ![Imagen](https://matematicasies.com/local/cache-vignettes/L546xH257/teorema_senos_2-932d7.png?1587880614)

# %%
#Solucion

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.26.46 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.33.03 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ## Ejercicio 3
# <p>
# Realizar un algoritmo que utilizando el teorema del Coseno solucione para un lado
# </p>
#
# ![Imagen](https://www.matesfacil.com/BAC/trigonometria/teorema/coseno/TCOS1.png)

# %%
#Solucion

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.35.13 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ## Ejercicio 4
# <p>
# Construya un algoritmo que calcule la distancia entre dos puntos P y Q, con los siguientes parámetros de entrada: X1, X2, Y1, Y2. Recuerde que los puntos se representan mediante coordenadas X e Y.
# </p>
#
# ![Imagen](https://es-static.z-dn.net/files/df1/350f474c6280b1180ba8d407c7eadb10.png)

# %%
#Solucion

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.45.43 a.m..png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.46.24 a.m..png](data:image/png;base64,...)

# %% [markdown]
# <p><a name="s2"></a></p>
#
# # **02. Listas, tuplas, diccionarios y conjuntos**
#
# ## (Conocidos como Python Collections (Arrays))
#
# [[Contenidos]](#contents)
#
#
# <p>
# Hay cuatro tipos de datos de datos vectorizados en el lenguaje de programación Python:
#
# *   List (Lista) es una colección ordenada y modificable. Permite miembros duplicados.
# *   Tuple (Tupla) es una colección ordenada e inmutable. Permite miembros duplicados.
# *   Set (Conjunto) es una colección que no está ordenada ni indexada. No hay miembros duplicados.
# *   Dictionary (Diccionario) es una colección desordenada y modificable. No hay miembros duplicados.
#
# Al elegir un tipo de colección, es útil conocer y comprender las propiedades de ese. Elegir el tipo correcto para un conjunto de datos podría significar un aumento en la eficiencia o la seguridad de los algoritmos. Seleccionar el tipo inadecuado casi siempre conlleva a subprocesos y largos tiempos de ejecución y en la mayoría de los casos código adicional no necesario.
#
#
#
# 1.   Crear una lista con 5 ítems (superhéroes de Marvel), agregar a la lista 3 superhéroes con la función `insert(posición,valor)`
# 2.   Crear una copia de la lista anterior usando la función `copy()` y adicionar 3 superhéroes con la función `append(valor)`
# 3.   Extender la lista del ejercicio 1 la lista del ejercicio 2 usando la función `extend(valor)`
# 4.   Eliminar un superhéroes de la lista 1 con la función `remove(valor)`
# 5.   Eliminar un superhéroes de la lista 1 con la función `pop(indice)`
# 6.   Crear una copia de la lista extendida usando `copy()` imprimirla y luego eliminar la lista con la instrucción `del`
# 7.   Crear una copia de la lista extendida usando `copy()` imprimirla y luego eliminar su contenido con la función  `clear()`
#
#
#
# </p>

# %%
#Ejercicios proxima clase

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.48.58 a.m..png](data:image/png;base64,...)

# %%
marvel = ["IronMan" , "Thor" , "Hulk" , "Capitan America" , "Spiderman"] #punto 1
print(marvel)
marvel.insert(1, "PanteraNegra")
print(marvel)
marvel.insert(4, "WinterSoldier")
print(marvel)
marvel.insert(5, "ViudaNegra")
print(marvel)
# Out:
# ['IronMan', 'Thor', 'Hulk', 'Capitan America', 'Spiderman']
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'Capitan America', 'Spiderman']
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'Capitan America', 'Spiderman']
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman']

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.51.03 a.m..png](data:image/png;base64,...)

# %%
marvel2 = marvel.copy() #punto 2
print(marvel2)
marvel2.append("Starlord")
marvel2.append("Vision")
marvel2.append("ScarletWitch")
print(marvel2)
print(marvel)
# Out:
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman']
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'Vision', 'ScarletWitch']
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman']

# %% [markdown]
# ![Captura de Pantalla 2023-10-17 a la(s) 9.53.13 a.m..png](data:image/png;base64,...)

# %%
marvel.extend(marvel2)#punto 3
print(marvel)
# Out:
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'Vision', 'ScarletWitch']

# %% [markdown]
# terminar los ejercicios  a partir del punto 4

# %%
marvel.remove("Thor")
print(marvel)
# Out:
# ['IronMan', 'PanteraNegra', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'Vision', 'ScarletWitch']

# %%
marvel2.remove("Vision")
print(marvel2)
# Out:
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'ScarletWitch']

# %%
marvel.pop(5)
print(marvel)
# Out:
# ['PanteraNegra', 'WinterSoldier', 'Spiderman', 'IronMan', 'PanteraNegra', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'Vision', 'ScarletWitch']

# %%
a= [7, 8,9,4,6,1]
a.sort()
print(a)
# Out:
# [1, 4, 6, 7, 8, 9]

# %%
marvel.sort()
print(marvel)
# Out:
# ['Capitan America', 'Hulk', 'IronMan', 'PanteraNegra', 'PanteraNegra', 'ScarletWitch', 'Spiderman', 'Spiderman', 'Starlord', 'Vision', 'ViudaNegra', 'WinterSoldier', 'WinterSoldier']

# %%
marvel.remove("Hulk") #punto 4
print(marvel)
# Out:
# ['Capitan America', 'IronMan', 'PanteraNegra', 'PanteraNegra', 'ScarletWitch', 'Spiderman', 'Spiderman', 'Starlord', 'Vision', 'ViudaNegra', 'WinterSoldier', 'WinterSoldier']

# %%
marvel.pop(5) #punto 5
print(marvel)
# Out:
# ['Capitan America', 'IronMan', 'PanteraNegra', 'PanteraNegra', 'ScarletWitch', 'Spiderman', 'Starlord', 'Vision', 'ViudaNegra', 'WinterSoldier', 'WinterSoldier']

# %%
marvel3 = marvel2.copy () # punto 6
print(marvel3)
print(len(marvel3))
del marvel3[1]
#marvel3.del[1]
print(marvel3)
print(len(marvel3))
# Out:
# ['IronMan', 'PanteraNegra', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'ScarletWitch']
# 10
# ['IronMan', 'Thor', 'Hulk', 'WinterSoldier', 'ViudaNegra', 'Capitan America', 'Spiderman', 'Starlord', 'ScarletWitch']
# 9

# %%
marvel4 = marvel.copy()
print(marvel4)
print(len(marvel4))
marvel4.clear()
print(marvel4)
print(len(marvel4))
# Out:
# ['Capitan America', 'IronMan', 'PanteraNegra', 'PanteraNegra', 'ScarletWitch', 'Spiderman', 'Starlord', 'Vision', 'ViudaNegra', 'WinterSoldier', 'WinterSoldier']
# 11
# []
# 0

# %%
marvel3.clear()
print(marvel3)
print(len(marvel3))
# Out:
# []
# 0

# %%
# !python --version
# Out:
# Python 3.10.12
